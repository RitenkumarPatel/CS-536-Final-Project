# %%
from GenerateTrainingData import GenerateTrainingData
import numpy as np

# %%
STD_DEV = 0.31622776601 # sqrt(0.1)
data_generator = GenerateTrainingData(num_features=101, STD_DEV=STD_DEV)

# %%
A_mat, B_vec, C_mat = data_generator.generate_data(num_data_points=1000)

# %%
print(np.linalg.norm(A_mat - C_mat))
print(np.linalg.norm(A_mat))
print(np.linalg.norm(C_mat))
# Out:
# 378.6047001442964
# 774.9022105889808
# 859.9451667821013

# %%
STD_DEV = 0.1
data_generator = GenerateTrainingData(num_features=101, STD_DEV=STD_DEV)
A_mat, B_vec, C_mat = data_generator.generate_data(num_data_points=1000)

# %%
print(np.linalg.norm(A_mat - C_mat))
print(np.linalg.norm(A_mat))
print(np.linalg.norm(C_mat))
# Out:
# 120.11758811980229
# 772.0082070666176
# 781.5903209654897
